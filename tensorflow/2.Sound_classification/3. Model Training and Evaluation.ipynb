# %% [markdown]
# ## 3. Model Training and Evaluation
#
# - Classifying(딥러닝을 사용해 urban sounds 분류하기)
#   * Model 생성 -> keras
#   * 학습(Training) -> model.fit
#   * 예측(Prediction) -> 함수 생성
#   * 평가(Validation) -> Prediction에서 생성한 함수 활용
#
# **Keras를 통해 3개의 layer를 가지는 Multilayer Perceptron(MLP) 신경망 구축을 통해 모델 학습 및 평가하기**

# %%
# 앞서 2번에서 전처리 완료된 데이터 저장한 것을 불러오기

# %store -r x_train 
# %store -r x_test 
# %store -r y_train 
# %store -r y_test 
# %store -r yy 
# %store -r le

# %%
import tensorflow as tf
import keras

print(tf.__version__)
# Out:
# 2.1.0
# Using TensorFlow backend.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.layers import LSTM
from sklearn import metrics 

num_labels = yy.shape[1] # 10
filter_size = 2

# Construct model 
model = keras.Sequential([
    keras.layers.Dense(256, activation='relu', input_shape=(40,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(256, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(num_labels, activation='softmax')
])

# %%
# 모델 컴파일 하기
# 손실함수는 classification에 가장 많이 쓰이는 categorical_crossentropy 사용(점수 낮으면 모델 성능 더 좋아짐)
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary() # 모델의 architecture summary

# pre-training 정확도 계산하기
score = model.evaluate(x_test, y_test, verbose=0)
accuracy = 100*score[1]

print("Pre-training accuracy: %.4f%%" % accuracy)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 256)               10496
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 78,858
# Trainable params: 78,858
# Non-trainable params: 0
# _________________________________________________________________
# Pre-training accuracy: 12.7075%

# %%
# Training
# 해당 모델에 대해 epoch 100회 실시(100번 반복) => 특정 시점에 도달할 때 까지 향상될 것
# batch size는 작게 설정(배치사이즈 크면 모델의 일반화 능력 감소시킬 수 있으므로)
from keras.callbacks import ModelCheckpoint 
from datetime import datetime 

num_epochs = 100
num_batch_size = 32
checkpoint_path = './saved_models/weights.best.basic_mlp.hdf5'

# 학습(Training)하는 동안 체크포인트 저장하기
# 훈련 중간과 마지막에 자동으로 저장하도록 옵션 설정(모델 재사용성 up!)
checkpointer = keras.callbacks.ModelCheckpoint(checkpoint_path,
                                                verbose=1, save_best_only=True)
start = datetime.now()

# 모델 학습(Training)
model.fit(x_train, y_train, 
          batch_size=num_batch_size, 
          epochs=num_epochs, 
          validation_data=(x_test, y_test), 
          callbacks=[checkpointer], 
          verbose=1)

duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Train on 6985 samples, validate on 1747 samples
# Epoch 1/100
# 6985/6985 [==============================] - 2s 257us/step - loss: 8.3857 - accuracy: 0.1871 - val_loss: 2.1452 - val_accuracy: 0.2433
#
# Epoch 00001: val_loss improved from inf to 2.14515, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 2/100
# 6985/6985 [==============================] - 1s 202us/step - loss: 2.2239 - accuracy: 0.2424 - val_loss: 1.9371 - val_accuracy: 0.3183
#
# Epoch 00002: val_loss improved from 2.14515 to 1.93710, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 3/100
# 6985/6985 [==============================] - 1s 197us/step - loss: 2.0027 - accuracy: 0.2882 - val_loss: 1.8018 - val_accuracy: 0.3869
#
# Epoch 00003: val_loss improved from 1.93710 to 1.80177, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 4/100
# 6985/6985 [==============================] - 1s 203us/step - loss: 1.8841 - accuracy: 0.3234 - val_loss: 1.6774 - val_accuracy: 0.4282
#
# Epoch 00004: val_loss improved from 1.80177 to 1.67735, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 5/100
# 6985/6985 [==============================] - 1s 201us/step - loss: 1.7564 - accuracy: 0.3655 - val_loss: 1.5872 - val_accuracy: 0.4390
#
# Epoch 00005: val_loss improved from 1.67735 to 1.58717, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 6/100
# 6985/6985 [==============================] - 1s 191us/step - loss: 1.6764 - accuracy: 0.4152 - val_loss: 1.4558 - val_accuracy: 0.5083
#
# Epoch 00006: val_loss improved from 1.58717 to 1.45580, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 7/100
# 6985/6985 [==============================] - 1s 208us/step - loss: 1.5507 - accuracy: 0.4555 - val_loss: 1.3176 - val_accuracy: 0.5575
#
# Epoch 00007: val_loss improved from 1.45580 to 1.31757, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 8/100
# 6985/6985 [==============================] - 1s 184us/step - loss: 1.4673 - accuracy: 0.4953 - val_loss: 1.2404 - val_accuracy: 0.5919
#
# Epoch 00008: val_loss improved from 1.31757 to 1.24044, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 9/100
# 6985/6985 [==============================] - 1s 179us/step - loss: 1.3826 - accuracy: 0.5244 - val_loss: 1.1156 - val_accuracy: 0.6451
#
# Epoch 00009: val_loss improved from 1.24044 to 1.11558, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 10/100
# 6985/6985 [==============================] - 1s 186us/step - loss: 1.3150 - accuracy: 0.5469 - val_loss: 1.0688 - val_accuracy: 0.6554
#
# Epoch 00010: val_loss improved from 1.11558 to 1.06876, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 11/100
# 6985/6985 [==============================] - 1s 197us/step - loss: 1.2591 - accuracy: 0.5671 - val_loss: 1.0352 - val_accuracy: 0.6783
#
# Epoch 00011: val_loss improved from 1.06876 to 1.03523, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 12/100
# 6985/6985 [==============================] - 1s 192us/step - loss: 1.2081 - accuracy: 0.5908 - val_loss: 1.0093 - val_accuracy: 0.6898
#
# Epoch 00012: val_loss improved from 1.03523 to 1.00926, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 13/100
# 6985/6985 [==============================] - 1s 176us/step - loss: 1.1661 - accuracy: 0.6013 - val_loss: 0.9408 - val_accuracy: 0.6938
#
# Epoch 00013: val_loss improved from 1.00926 to 0.94085, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 14/100
# 6985/6985 [==============================] - 1s 201us/step - loss: 1.1340 - accuracy: 0.6122 - val_loss: 0.9199 - val_accuracy: 0.7127
#
# Epoch 00014: val_loss improved from 0.94085 to 0.91991, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 15/100
# 6985/6985 [==============================] - 1s 186us/step - loss: 1.0831 - accuracy: 0.6286 - val_loss: 0.8583 - val_accuracy: 0.7373
#
# Epoch 00015: val_loss improved from 0.91991 to 0.85834, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 16/100
# 6985/6985 [==============================] - 1s 184us/step - loss: 1.0490 - accuracy: 0.6462 - val_loss: 0.8167 - val_accuracy: 0.7355
#
# Epoch 00016: val_loss improved from 0.85834 to 0.81671, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 17/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 1.0217 - accuracy: 0.6554 - val_loss: 0.8034 - val_accuracy: 0.7527
#
# Epoch 00017: val_loss improved from 0.81671 to 0.80336, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 18/100
# 6985/6985 [==============================] - 1s 186us/step - loss: 1.0022 - accuracy: 0.6584 - val_loss: 0.7883 - val_accuracy: 0.7510
#
# Epoch 00018: val_loss improved from 0.80336 to 0.78834, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 19/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 0.9748 - accuracy: 0.6691 - val_loss: 0.7657 - val_accuracy: 0.7567
#
# Epoch 00019: val_loss improved from 0.78834 to 0.76570, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 20/100
# 6985/6985 [==============================] - 1s 191us/step - loss: 0.9389 - accuracy: 0.6822 - val_loss: 0.7385 - val_accuracy: 0.7785
#
# Epoch 00020: val_loss improved from 0.76570 to 0.73850, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 21/100
# 6985/6985 [==============================] - 1s 194us/step - loss: 0.9155 - accuracy: 0.6872 - val_loss: 0.6889 - val_accuracy: 0.7888
#
# Epoch 00021: val_loss improved from 0.73850 to 0.68894, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 22/100
# 6985/6985 [==============================] - 1s 175us/step - loss: 0.9024 - accuracy: 0.6921 - val_loss: 0.6748 - val_accuracy: 0.7974
#
# Epoch 00022: val_loss improved from 0.68894 to 0.67481, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 23/100
# 6985/6985 [==============================] - 1s 183us/step - loss: 0.8748 - accuracy: 0.7037 - val_loss: 0.6741 - val_accuracy: 0.7928
#
# Epoch 00023: val_loss improved from 0.67481 to 0.67413, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 24/100
# 6985/6985 [==============================] - 1s 187us/step - loss: 0.8523 - accuracy: 0.7102 - val_loss: 0.6505 - val_accuracy: 0.7991
#
# Epoch 00024: val_loss improved from 0.67413 to 0.65050, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 25/100
# 6985/6985 [==============================] - 1s 184us/step - loss: 0.8226 - accuracy: 0.7162 - val_loss: 0.6325 - val_accuracy: 0.8145
#
# Epoch 00025: val_loss improved from 0.65050 to 0.63252, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 26/100
# 6985/6985 [==============================] - 1s 181us/step - loss: 0.8139 - accuracy: 0.7233 - val_loss: 0.5833 - val_accuracy: 0.8243
#
# Epoch 00026: val_loss improved from 0.63252 to 0.58327, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 27/100
# 6985/6985 [==============================] - 1s 183us/step - loss: 0.8185 - accuracy: 0.7307 - val_loss: 0.6129 - val_accuracy: 0.8163
#
# Epoch 00027: val_loss did not improve from 0.58327
# Epoch 28/100
# 6985/6985 [==============================] - 1s 202us/step - loss: 0.8064 - accuracy: 0.7236 - val_loss: 0.6029 - val_accuracy: 0.8163
#
# Epoch 00028: val_loss did not improve from 0.58327
# Epoch 29/100
# 6985/6985 [==============================] - 1s 190us/step - loss: 0.7823 - accuracy: 0.7334 - val_loss: 0.5819 - val_accuracy: 0.8226
#
# Epoch 00029: val_loss improved from 0.58327 to 0.58189, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 30/100
# 6985/6985 [==============================] - 2s 230us/step - loss: 0.7632 - accuracy: 0.7392 - val_loss: 0.5751 - val_accuracy: 0.8277
#
# Epoch 00030: val_loss improved from 0.58189 to 0.57514, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 31/100
# 6985/6985 [==============================] - 1s 192us/step - loss: 0.7558 - accuracy: 0.7452 - val_loss: 0.5907 - val_accuracy: 0.8329
#
# Epoch 00031: val_loss did not improve from 0.57514
# Epoch 32/100
# 6985/6985 [==============================] - 1s 186us/step - loss: 0.7492 - accuracy: 0.7435 - val_loss: 0.6051 - val_accuracy: 0.8168
#
# Epoch 00032: val_loss did not improve from 0.57514
# Epoch 33/100
# 6985/6985 [==============================] - 1s 176us/step - loss: 0.7469 - accuracy: 0.7432 - val_loss: 0.5632 - val_accuracy: 0.8306
#
# Epoch 00033: val_loss improved from 0.57514 to 0.56319, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 34/100
# 6985/6985 [==============================] - 1s 186us/step - loss: 0.7366 - accuracy: 0.7522 - val_loss: 0.5605 - val_accuracy: 0.8283
#
# Epoch 00034: val_loss improved from 0.56319 to 0.56054, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 35/100
# 6985/6985 [==============================] - 1s 197us/step - loss: 0.7029 - accuracy: 0.7606 - val_loss: 0.5630 - val_accuracy: 0.8294
#
# Epoch 00035: val_loss did not improve from 0.56054
# Epoch 36/100
# 6985/6985 [==============================] - 1s 176us/step - loss: 0.6925 - accuracy: 0.7635 - val_loss: 0.5481 - val_accuracy: 0.8363
#
# Epoch 00036: val_loss improved from 0.56054 to 0.54813, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 37/100
# 6985/6985 [==============================] - 2s 238us/step - loss: 0.7052 - accuracy: 0.7701 - val_loss: 0.5520 - val_accuracy: 0.8294
#
# Epoch 00037: val_loss did not improve from 0.54813
# Epoch 38/100
# 6985/6985 [==============================] - 1s 185us/step - loss: 0.6972 - accuracy: 0.7632 - val_loss: 0.5449 - val_accuracy: 0.8329
#
# Epoch 00038: val_loss improved from 0.54813 to 0.54495, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 39/100
# 6985/6985 [==============================] - 2s 244us/step - loss: 0.6956 - accuracy: 0.7646 - val_loss: 0.5313 - val_accuracy: 0.8346
#
# Epoch 00039: val_loss improved from 0.54495 to 0.53134, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 40/100
# 6985/6985 [==============================] - 2s 265us/step - loss: 0.6622 - accuracy: 0.7672 - val_loss: 0.5082 - val_accuracy: 0.8489
#
# Epoch 00040: val_loss improved from 0.53134 to 0.50820, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 41/100
# 6985/6985 [==============================] - 1s 195us/step - loss: 0.6644 - accuracy: 0.7742 - val_loss: 0.5123 - val_accuracy: 0.8392
#
# Epoch 00041: val_loss did not improve from 0.50820
# Epoch 42/100
# 6985/6985 [==============================] - 2s 292us/step - loss: 0.6664 - accuracy: 0.7711 - val_loss: 0.5231 - val_accuracy: 0.8323
#
# Epoch 00042: val_loss did not improve from 0.50820
# Epoch 43/100
# 6985/6985 [==============================] - 2s 219us/step - loss: 0.6570 - accuracy: 0.7764 - val_loss: 0.5099 - val_accuracy: 0.8454
#
# Epoch 00043: val_loss did not improve from 0.50820
# Epoch 44/100
# 6985/6985 [==============================] - 1s 207us/step - loss: 0.6536 - accuracy: 0.7794 - val_loss: 0.5142 - val_accuracy: 0.8306
#
# Epoch 00044: val_loss did not improve from 0.50820
# Epoch 45/100
# 6985/6985 [==============================] - 2s 251us/step - loss: 0.6674 - accuracy: 0.7708 - val_loss: 0.5290 - val_accuracy: 0.8495
#
# Epoch 00045: val_loss did not improve from 0.50820
# Epoch 46/100
# 6985/6985 [==============================] - 1s 192us/step - loss: 0.6299 - accuracy: 0.7818 - val_loss: 0.5029 - val_accuracy: 0.8414
#
# Epoch 00046: val_loss improved from 0.50820 to 0.50293, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 47/100
# 6985/6985 [==============================] - 1s 188us/step - loss: 0.6474 - accuracy: 0.7843 - val_loss: 0.4938 - val_accuracy: 0.8540
#
# Epoch 00047: val_loss improved from 0.50293 to 0.49382, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 48/100
# 6985/6985 [==============================] - 1s 187us/step - loss: 0.6390 - accuracy: 0.7858 - val_loss: 0.4996 - val_accuracy: 0.8558
#
# Epoch 00048: val_loss did not improve from 0.49382
# Epoch 49/100
# 6985/6985 [==============================] - 2s 234us/step - loss: 0.6410 - accuracy: 0.7791 - val_loss: 0.5031 - val_accuracy: 0.8552
#
# Epoch 00049: val_loss did not improve from 0.49382
# Epoch 50/100
# 6985/6985 [==============================] - 2s 219us/step - loss: 0.6483 - accuracy: 0.7787 - val_loss: 0.5131 - val_accuracy: 0.8495
#
# Epoch 00050: val_loss did not improve from 0.49382
# Epoch 51/100
# 6985/6985 [==============================] - 1s 200us/step - loss: 0.6171 - accuracy: 0.7914 - val_loss: 0.4855 - val_accuracy: 0.8609
#
# Epoch 00051: val_loss improved from 0.49382 to 0.48546, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 52/100
# 6985/6985 [==============================] - 1s 192us/step - loss: 0.6059 - accuracy: 0.7967 - val_loss: 0.5015 - val_accuracy: 0.8535
#
# Epoch 00052: val_loss did not improve from 0.48546
# Epoch 53/100
# 6985/6985 [==============================] - 1s 203us/step - loss: 0.6282 - accuracy: 0.7913 - val_loss: 0.4973 - val_accuracy: 0.8483
#
# Epoch 00053: val_loss did not improve from 0.48546
# Epoch 54/100
# 6985/6985 [==============================] - 2s 228us/step - loss: 0.6241 - accuracy: 0.7900 - val_loss: 0.4821 - val_accuracy: 0.8466
#
# Epoch 00054: val_loss improved from 0.48546 to 0.48213, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 55/100
# 6985/6985 [==============================] - 2s 235us/step - loss: 0.5908 - accuracy: 0.7973 - val_loss: 0.4659 - val_accuracy: 0.8643
#
# Epoch 00055: val_loss improved from 0.48213 to 0.46595, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 56/100
# 6985/6985 [==============================] - 1s 197us/step - loss: 0.6189 - accuracy: 0.7888 - val_loss: 0.4601 - val_accuracy: 0.8706
#
# Epoch 00056: val_loss improved from 0.46595 to 0.46009, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 57/100
# 6985/6985 [==============================] - 1s 173us/step - loss: 0.5927 - accuracy: 0.8011 - val_loss: 0.4571 - val_accuracy: 0.8603
#
# Epoch 00057: val_loss improved from 0.46009 to 0.45711, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 58/100
# 6985/6985 [==============================] - 1s 175us/step - loss: 0.5861 - accuracy: 0.8019 - val_loss: 0.4747 - val_accuracy: 0.8569
#
# Epoch 00058: val_loss did not improve from 0.45711
# Epoch 59/100
# 6985/6985 [==============================] - 1s 180us/step - loss: 0.5969 - accuracy: 0.8004 - val_loss: 0.4582 - val_accuracy: 0.8586
#
# Epoch 00059: val_loss did not improve from 0.45711
# Epoch 60/100
# 6985/6985 [==============================] - 1s 184us/step - loss: 0.6081 - accuracy: 0.7887 - val_loss: 0.4757 - val_accuracy: 0.8598
#
# Epoch 00060: val_loss did not improve from 0.45711
# Epoch 61/100
# 6985/6985 [==============================] - 1s 187us/step - loss: 0.5710 - accuracy: 0.8040 - val_loss: 0.4629 - val_accuracy: 0.8661
#
# Epoch 00061: val_loss did not improve from 0.45711
# Epoch 62/100
# 6985/6985 [==============================] - 1s 199us/step - loss: 0.5699 - accuracy: 0.8064 - val_loss: 0.4813 - val_accuracy: 0.8603
#
# Epoch 00062: val_loss did not improve from 0.45711
# Epoch 63/100
# 6985/6985 [==============================] - 1s 198us/step - loss: 0.5680 - accuracy: 0.8096 - val_loss: 0.4795 - val_accuracy: 0.8632
#
# Epoch 00063: val_loss did not improve from 0.45711
# Epoch 64/100
# 6985/6985 [==============================] - 1s 174us/step - loss: 0.6190 - accuracy: 0.7979 - val_loss: 0.4672 - val_accuracy: 0.8615
#
# Epoch 00064: val_loss did not improve from 0.45711
# Epoch 65/100
# 6985/6985 [==============================] - 1s 174us/step - loss: 0.5807 - accuracy: 0.7961 - val_loss: 0.4708 - val_accuracy: 0.8655
#
# Epoch 00065: val_loss did not improve from 0.45711
# Epoch 66/100
# 6985/6985 [==============================] - 2s 219us/step - loss: 0.5629 - accuracy: 0.8069 - val_loss: 0.4519 - val_accuracy: 0.8666
#
# Epoch 00066: val_loss improved from 0.45711 to 0.45187, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 67/100
# 6985/6985 [==============================] - 1s 184us/step - loss: 0.5842 - accuracy: 0.8013 - val_loss: 0.4562 - val_accuracy: 0.8701
#
# Epoch 00067: val_loss did not improve from 0.45187
# Epoch 68/100
# 6985/6985 [==============================] - 1s 165us/step - loss: 0.5820 - accuracy: 0.8031 - val_loss: 0.4564 - val_accuracy: 0.8615
#
# Epoch 00068: val_loss did not improve from 0.45187
# Epoch 69/100
# 6985/6985 [==============================] - 1s 187us/step - loss: 0.5766 - accuracy: 0.8082 - val_loss: 0.4648 - val_accuracy: 0.8615
# Epoch 00069: val_loss did not improve from 0.45187
# Epoch 70/100
# 6985/6985 [==============================] - 1s 173us/step - loss: 0.5800 - accuracy: 0.8074 - val_loss: 0.4520 - val_accuracy: 0.8695
#
# Epoch 00070: val_loss did not improve from 0.45187
# Epoch 71/100
# 6985/6985 [==============================] - 2s 332us/step - loss: 0.5627 - accuracy: 0.8115 - val_loss: 0.4455 - val_accuracy: 0.8678
#
# Epoch 00071: val_loss improved from 0.45187 to 0.44554, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 72/100
# 6985/6985 [==============================] - 2s 228us/step - loss: 0.5554 - accuracy: 0.8113 - val_loss: 0.4390 - val_accuracy: 0.8712
#
# Epoch 00072: val_loss improved from 0.44554 to 0.43901, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 73/100
# 6985/6985 [==============================] - 2s 227us/step - loss: 0.5549 - accuracy: 0.8117 - val_loss: 0.4488 - val_accuracy: 0.8683
#
# Epoch 00073: val_loss did not improve from 0.43901
# Epoch 74/100
# 6985/6985 [==============================] - 2s 216us/step - loss: 0.5597 - accuracy: 0.8132 - val_loss: 0.4344 - val_accuracy: 0.8781
#
# Epoch 00074: val_loss improved from 0.43901 to 0.43436, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 75/100
# 6985/6985 [==============================] - 1s 198us/step - loss: 0.5578 - accuracy: 0.8173 - val_loss: 0.4560 - val_accuracy: 0.8655
#
# Epoch 00075: val_loss did not improve from 0.43436
# Epoch 76/100
# 6985/6985 [==============================] - 1s 190us/step - loss: 0.5401 - accuracy: 0.8099 - val_loss: 0.4531 - val_accuracy: 0.8661
#
# Epoch 00076: val_loss did not improve from 0.43436
# Epoch 77/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 0.5585 - accuracy: 0.8155 - val_loss: 0.4678 - val_accuracy: 0.8672
#
# Epoch 00077: val_loss did not improve from 0.43436
# Epoch 78/100
# 6985/6985 [==============================] - 1s 173us/step - loss: 0.5720 - accuracy: 0.8067 - val_loss: 0.4798 - val_accuracy: 0.8683
#
# Epoch 00078: val_loss did not improve from 0.43436
# Epoch 79/100
# 6985/6985 [==============================] - 1s 195us/step - loss: 0.5444 - accuracy: 0.8166 - val_loss: 0.4541 - val_accuracy: 0.8775
#
# Epoch 00079: val_loss did not improve from 0.43436
# Epoch 80/100
# 6985/6985 [==============================] - 1s 191us/step - loss: 0.5402 - accuracy: 0.8162 - val_loss: 0.4500 - val_accuracy: 0.8792
#
# Epoch 00080: val_loss did not improve from 0.43436
# Epoch 81/100
# 6985/6985 [==============================] - 1s 175us/step - loss: 0.5474 - accuracy: 0.8199 - val_loss: 0.4425 - val_accuracy: 0.8724
#
# Epoch 00081: val_loss did not improve from 0.43436
# Epoch 82/100
# 6985/6985 [==============================] - 1s 195us/step - loss: 0.5381 - accuracy: 0.8198 - val_loss: 0.4465 - val_accuracy: 0.8832
#
# Epoch 00082: val_loss did not improve from 0.43436
# Epoch 83/100
# 6985/6985 [==============================] - 1s 180us/step - loss: 0.5446 - accuracy: 0.8126 - val_loss: 0.4209 - val_accuracy: 0.8798
#
# Epoch 00083: val_loss improved from 0.43436 to 0.42091, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 84/100
# 6985/6985 [==============================] - 1s 177us/step - loss: 0.5308 - accuracy: 0.8202 - val_loss: 0.4440 - val_accuracy: 0.8746
#
# Epoch 00084: val_loss did not improve from 0.42091
# Epoch 85/100
# 6985/6985 [==============================] - 1s 191us/step - loss: 0.5413 - accuracy: 0.8146 - val_loss: 0.4219 - val_accuracy: 0.8712
#
# Epoch 00085: val_loss did not improve from 0.42091
# Epoch 86/100
# 6985/6985 [==============================] - 1s 177us/step - loss: 0.5384 - accuracy: 0.8203 - val_loss: 0.4355 - val_accuracy: 0.8712
#
# Epoch 00086: val_loss did not improve from 0.42091
# Epoch 87/100
# 6985/6985 [==============================] - 1s 196us/step - loss: 0.5113 - accuracy: 0.8306 - val_loss: 0.4169 - val_accuracy: 0.8764
#
# Epoch 00087: val_loss improved from 0.42091 to 0.41694, saving model to ./saved_models/weights.best.basic_mlp.hdf5
# Epoch 88/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 0.5390 - accuracy: 0.8219 - val_loss: 0.4642 - val_accuracy: 0.8666
#
# Epoch 00088: val_loss did not improve from 0.41694
# Epoch 89/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 0.5462 - accuracy: 0.8245 - val_loss: 0.4533 - val_accuracy: 0.8758
#
# Epoch 00089: val_loss did not improve from 0.41694
# Epoch 90/100
# 6985/6985 [==============================] - 1s 208us/step - loss: 0.5194 - accuracy: 0.8263 - val_loss: 0.4407 - val_accuracy: 0.8735
#
# Epoch 00090: val_loss did not improve from 0.41694
# Epoch 91/100
# 6985/6985 [==============================] - 1s 181us/step - loss: 0.5237 - accuracy: 0.8213 - val_loss: 0.4324 - val_accuracy: 0.8798
#
# Epoch 00091: val_loss did not improve from 0.41694
# Epoch 92/100
# 6985/6985 [==============================] - 1s 182us/step - loss: 0.5439 - accuracy: 0.8170 - val_loss: 0.4189 - val_accuracy: 0.8769
#
# Epoch 00092: val_loss did not improve from 0.41694
# Epoch 93/100
# 6985/6985 [==============================] - 1s 177us/step - loss: 0.5194 - accuracy: 0.8281 - val_loss: 0.4489 - val_accuracy: 0.8655
#
# Epoch 00093: val_loss did not improve from 0.41694
# Epoch 94/100
# 6985/6985 [==============================] - 1s 188us/step - loss: 0.5226 - accuracy: 0.8223 - val_loss: 0.4567 - val_accuracy: 0.8683
#
# Epoch 00094: val_loss did not improve from 0.41694
# Epoch 95/100
# 6985/6985 [==============================] - 1s 169us/step - loss: 0.5050 - accuracy: 0.8314 - val_loss: 0.4342 - val_accuracy: 0.8821
#
# Epoch 00095: val_loss did not improve from 0.41694
# Epoch 96/100
# 6985/6985 [==============================] - 1s 174us/step - loss: 0.5270 - accuracy: 0.8223 - val_loss: 0.4419 - val_accuracy: 0.8706
#
# Epoch 00096: val_loss did not improve from 0.41694
# Epoch 97/100
# 6985/6985 [==============================] - 1s 180us/step - loss: 0.5332 - accuracy: 0.8216 - val_loss: 0.4493 - val_accuracy: 0.8695
#
# Epoch 00097: val_loss did not improve from 0.41694
# Epoch 98/100
# 6985/6985 [==============================] - 1s 180us/step - loss: 0.5160 - accuracy: 0.8275 - val_loss: 0.4550 - val_accuracy: 0.8701
#
# Epoch 00098: val_loss did not improve from 0.41694
# Epoch 99/100
# 6985/6985 [==============================] - 1s 175us/step - loss: 0.5043 - accuracy: 0.8279 - val_loss: 0.4391 - val_accuracy: 0.8729
#
# Epoch 00099: val_loss did not improve from 0.41694
# Epoch 100/100
# 6985/6985 [==============================] - 1s 180us/step - loss: 0.5208 - accuracy: 0.8245 - val_loss: 0.4428 - val_accuracy: 0.8809
#
# Epoch 00100: val_loss did not improve from 0.41694
# Training completed in time:  0:02:20.409723

# %%
import os 

checkpoint_dir = os.path.dirname(checkpoint_path)

# !ls {checkpoint_dir}
# Out:
# weights.best.basic_mlp.hdf5

# %%
# 모델 테스트하기(결과 차이가 아주 조금인 약 0.04 발생하는 것은 과적합이 아니라는 것을 의미)
# => 잘 훈련된 모델!

# Training set의 정확도 
score = model.evaluate(x_train, y_train, verbose=0)
print("Training Accuracy: ", score[1])

# Test set의 정확도
score = model.evaluate(x_test, y_test, verbose=0)
print("Testing Accuracy: ", score[1])
# Out:
# Training Accuracy:  0.9248389601707458
# Testing Accuracy:  0.8809387683868408

# %%
# Prediction(예측하기) => 특정 .wav 파일 불러와서 예측하는 함수 생성
import librosa 
import numpy as np 

def extract_feature(file_name):
    try:
        audio_data, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        mfccs = librosa.feature.mfcc(y=audio_data, sr=sample_rate, n_mfcc=40)
        mfccsscaled = np.mean(mfccs.T,axis=0)
        
    except Exception as e:
        print("Error encountered while parsing file: ", file)
        return None, None

    return np.array([mfccsscaled])

# %%
def print_prediction(file_name):
    prediction_feature = extract_feature(file_name) 

    predicted_vector = model.predict_classes(prediction_feature)
    predicted_class = le.inverse_transform(predicted_vector) 
    print("The predicted class is:", predicted_class[0], '\n') 

    predicted_proba_vector = model.predict_proba(prediction_feature) 
    predicted_proba = predicted_proba_vector[0]
    for i in range(len(predicted_proba)): 
        category = le.inverse_transform(np.array([i]))
        print(category[0], "\t\t : ", format(predicted_proba[i], '.32f') )

# %%
# Validation
# 1번 쥬피터에서 확인했던 파일을 불러와 평가(예측)해보기

import IPython.display as ipd

filename = './UrbanSound8K/audio/fold1/180937-7-2-1.wav' # 드릴(착음기)소리
ipd.Audio(filename)
print_prediction(filename)
# Out:
# The predicted class is: jackhammer
#
# air_conditioner 		 :  0.00000007911994970299929264001548
# car_horn 		 :  0.00000876384729053825139999389648
# children_playing 		 :  0.00000047031798544594494160264730
# dog_bark 		 :  0.00000001747014977127037127502263
# drilling 		 :  0.00002442583172523882240056991577
# engine_idling 		 :  0.00000000209675699025524409080390
# gun_shot 		 :  0.00000000283887136021121477824636
# jackhammer 		 :  0.99996364116668701171875000000000
# siren 		 :  0.00000091087048303961637429893017
# street_music 		 :  0.00000160393108217249391600489616

# %%
filename = './UrbanSound8K/audio/fold5/100852-0-0-0.wav' # 에어컨소리
ipd.Audio(filename)
print_prediction(filename)
# Out:
# The predicted class is: air_conditioner
#
# air_conditioner 		 :  0.99999964237213134765625000000000
# car_horn 		 :  0.00000000202525374248807565891184
# children_playing 		 :  0.00000000560530599713615629298147
# dog_bark 		 :  0.00000000050791471029043577800621
# drilling 		 :  0.00000026281065856892382726073265
# engine_idling 		 :  0.00000006883440306637567118741572
# gun_shot 		 :  0.00000000000583838966755623189897
# jackhammer 		 :  0.00000001565264184932857460808009
# siren 		 :  0.00000000000237798626276375379973
# street_music 		 :  0.00000000162685298565889979727217

# %%
filename = './UrbanSound8K/audio/fold7/101848-9-0-0.wav' # 거리음악 소리
ipd.Audio(filename)
print_prediction(filename)
# Out:
# The predicted class is: street_music
#
# air_conditioner 		 :  0.00524505879729986190795898437500
# car_horn 		 :  0.00082799512892961502075195312500
# children_playing 		 :  0.04531287774443626403808593750000
# dog_bark 		 :  0.00366795668378472328186035156250
# drilling 		 :  0.00080098351463675498962402343750
# engine_idling 		 :  0.00529348896816372871398925781250
# gun_shot 		 :  0.00067102635512128472328186035156
# jackhammer 		 :  0.00991755258291959762573242187500
# siren 		 :  0.00024422770366072654724121093750
# street_music 		 :  0.92801880836486816406250000000000

# %%
filename = './UrbanSound8K/audio/fold10/100648-1-0-0.wav' # 차 경적소리
ipd.Audio(filename)
print_prediction(filename)
# Out:
# The predicted class is: street_music
#
# air_conditioner 		 :  0.03475644811987876892089843750000
# car_horn 		 :  0.03183532506227493286132812500000
# children_playing 		 :  0.17433208227157592773437500000000
# dog_bark 		 :  0.14379122853279113769531250000000
# drilling 		 :  0.08944501727819442749023437500000
# engine_idling 		 :  0.03119277395308017730712890625000
# gun_shot 		 :  0.07807990163564682006835937500000
# jackhammer 		 :  0.02646535448729991912841796875000
# siren 		 :  0.01510414294898509979248046875000
# street_music 		 :  0.37499770522117614746093750000000

# %%
filename = './children.wav' # 애들 뛰노는 소리
# ipd.Audio(filename)
print_prediction(filename)
# Out:
# The predicted class is: children_playing
#
# air_conditioner 		 :  0.00021424313308671116828918457031
# car_horn 		 :  0.00022006606741342693567276000977
# children_playing 		 :  0.38865002989768981933593750000000
# dog_bark 		 :  0.33827415108680725097656250000000
# drilling 		 :  0.04806090518832206726074218750000
# engine_idling 		 :  0.00154160428792238235473632812500
# gun_shot 		 :  0.19597542285919189453125000000000
# jackhammer 		 :  0.00002670191861398052424192428589
# siren 		 :  0.01512144505977630615234375000000
# street_music 		 :  0.01191546581685543060302734375000

# %% [markdown]
# 제일 마지막 '차 경적소리'를 '거리음악 소리'로 잘못 분류한 것을 제외하면
# 거의 정확한 일치율을 보임!
#
# 유튜브에서 가져온 아이들 뛰노는 소리도 구분 완료
